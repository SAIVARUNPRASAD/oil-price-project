# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"C:\Users\ASUS Vivobook\Downloads\Oil_Prices.csv")
data
# Out:
#              Date   Price
# 0     Jul 26, 2023   78.78
# 1     Jul 25, 2023   79.63
# 2     Jul 24, 2023   78.74
# 3     Jul 21, 2023   77.07
# 4     Jul 20, 2023   75.63
# ...            ...     ...
# 8548  Jan 08, 1990   21.62
# 8549  Jan 05, 1990   23.08
# 8550  Jan 04, 1990   23.41
# 8551  Jan 03, 1990   23.68
# 8552  Jan 02, 1990   22.89
#
# [8553 rows x 2 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8553 entries, 0 to 8552
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    8553 non-null   object
#  1   Price   8553 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 133.8+ KB

# %%
data.isna().sum()
# Out:
# Price     0
# dtype: int64

# %%
data.describe()
# Out:
#             Price
# count  8553.000000
# mean     50.253699
# std      29.351450
# min     -37.630000
# 25%      22.000000
# 50%      46.250000
# 75%      71.980000
# max     145.290000

# %%
data = pd.read_csv(r"C:\Users\ASUS Vivobook\Downloads\Oil_Prices.csv", index_col=0, header=0, parse_dates=True)
data
# Out:
#             Price
# Date
# 2023-07-26   78.78
# 2023-07-25   79.63
# 2023-07-24   78.74
# 2023-07-21   77.07
# 2023-07-20   75.63
# ...            ...
# 1990-01-08   21.62
# 1990-01-05   23.08
# 1990-01-04   23.41
# 1990-01-03   23.68
# 1990-01-02   22.89
#
# [8553 rows x 1 columns]

# %%
data.shape
# Out:
# (8553, 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 8553 entries, 2023-07-26 to 1990-01-02
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   8553 non-null   float64
# dtypes: float64(1)
# memory usage: 133.6 KB

# %%
data.index
# Out:
# DatetimeIndex(['2023-07-26', '2023-07-25', '2023-07-24', '2023-07-21',
#                '2023-07-20', '2023-07-19', '2023-07-18', '2023-07-17',
#                '2023-07-14', '2023-07-13',
#                ...
#                '1990-01-15', '1990-01-12', '1990-01-11', '1990-01-10',
#                '1990-01-09', '1990-01-08', '1990-01-05', '1990-01-04',
#                '1990-01-03', '1990-01-02'],
#               dtype='datetime64[ns]', name='Date ', length=8553, freq=None)

# %%
#Series Plot
plt.figure(figsize = (20,8))
plt.plot(data)

# %%
# create a histogram plot
data.hist()
# Out:
# array([[<Axes: title={'center': 'Price '}>]], dtype=object)

# %%
# create a density plot
data.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
#Lag plot
# create a scatter plot
plt.figure(figsize = (20,8))
pd.plotting.lag_plot(data)
# Out:
# <Axes: xlabel='y(t)', ylabel='y(t + 1)'>

# %%
# create an autocorrelation plot
from statsmodels.graphics.tsaplots import plot_acf

plt.figure(figsize = (60,15))
plot_acf(data, lags = 90)
plt.show()

# %%
plt.figure(figsize = (60,15))
plot_acf(data, lags = 365)
plt.show()
